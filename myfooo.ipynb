# %% [markdown]
# <a href="https://colab.research.google.com/github/amegh-ts/API/blob/main/myfooo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y cupy-cuda12x cupy
# !pip install numpy==1.26.4 cupy-cuda12x==13.3.0 pygit2==1.15.1

# %%
# 1. Clean up conflicting packages
# %cd /content
# !rm -rf /content/Fooocus

# 2. Clone a fresh copy of Fooocus
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus

# 3. FIX THE GRADIO/FASTAPI DICT BUG
# We append the exact compatible FastAPI versions directly to Fooocus's requirements
# Fooocus will automatically downgrade them during the "Installing requirements" phase
# !echo "" >> requirements_versions.txt
# !echo "fastapi==0.104.1" >> requirements_versions.txt
# !echo "starlette==0.27.0" >> requirements_versions.txt
# !echo "pydantic==1.10.19" >> requirements_versions.txt

# %%
# !curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/checkpoints/LucentXLPony.safetensors \
"https://civitai.com/api/download/models/1971591?type=Model&format=SafeTensor&size=full&fp=fp16"

# %%
# !curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/loras/HourGlassBodyPonny.safetensors \
"https://civitai.com/api/download/models/1096353?type=Model&format=SafeTensor" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/checkpoints/LUSTIFY_inpaint.safetensors \
"https://civitai.red/api/download/models/2875936?fileId=2756970" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/checkpoints/LUSTIFY.safetensors \
"https://civitai.red/api/download/models/3045803?fileId=2924520" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/checkpoints/LUSTIFY_olt_inpaint.safetensors \
"https://civitai.red/api/download/models/1588039?fileId=1487829" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/checkpoints/BigLust.safetensors \
"https://civitai.com/api/download/models/1081768?fileId=986850" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/loras/LEAKCORE.safetensors \
"https://civitai.red/api/download/models/1627770?fileId=1528309" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/loras/photorealism_LEAKCORE.safetensors \
"https://civitai.red/api/download/models/3244927?fileId=3128734" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/checkpoints/LucentXLPony.safetensors \
"https://civitai.com/api/download/models/1971591?type=Model&format=SafeTensor&size=full&fp=fp16"

# %%
# !python entry_with_update.py --share --always-high-vram --all-in-fp16 --listen
