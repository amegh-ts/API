# %% [markdown]
# <a href="https://colab.research.google.com/github/amegh-ts/API/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus

# %%
# !pip install "numpy<2.0" "cupy-cuda12x<14.0" --force-reinstall

# %%
# !curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/checkpoints/LucentXLPony.safetensors \
"https://civitai.com/api/download/models/1971591?type=Model&format=SafeTensor&size=full&fp=fp16"

# %%
# !curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/loras/HourGlassBodyPonny.safetensors \
"https://civitai.com/api/download/models/1096353?type=Model&format=SafeTensor" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/checkpoints/RealisticVision.safetensors \
"https://civitai.com/api/download/models/501286?type=Model&format=SafeTensor&size=full&fp=fp16" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/loras/PuffyBreastsSliderPonny.safetensors \
"https://civitai.com/api/download/models/1726904?type=Model&format=SafeTensor" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/loras/RealSkinSliderPonny.safetensors \
"https://civitai.com/api/download/models/1681921?type=Model&format=SafeTensor" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/loras/Tentacles.safetensors \
"https://civitai.com/api/download/models/700744?type=Model&format=SafeTensor" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/loras/largeflatbreasts.safetensors \
"https://civitai.com/api/download/models/466953?type=Model&format=SafeTensor" && \
curl -L \
-H "Authorization: Bearer 8f31faecfcd426f3d8eb88276c1d6b4c" \
-o /content/Fooocus/models/loras/hour-glass.safetensors \
"https://civitai.com/api/download/models/484498?type=Model&format=SafeTensor"

# %%
# !python entry_with_update.py --share --always-high-vram
